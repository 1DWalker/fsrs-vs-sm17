# %% [markdown]
# The cross comparison method is proposed by Woz: https://supermemo.guru/wiki/Universal_metric_for_cross-comparison_of_spaced_repetition_algorithms#Algorithmic_contest:_SuperMemo_2_vs._SuperMemo_17

# %%
import pandas as pd
from pathlib import Path

dfs = []

for file in Path("./raw").glob("*.csv"):
    dfs.append(pd.read_csv(file))

df = pd.concat(dfs, ignore_index=True)
df.rename(columns={"R (SM17)": "R (SM-17)"}, inplace=True)
df.rename(columns={"R (SM16)": "R (SM-16)"}, inplace=True)
df.head()
# Out:
#    y  R (SM-16)  R (SM-17)   R (AVG)  R (MOVING-AVG)  R (FSRS-6-default)  \
# 0  1      0.836      0.764  0.900000        0.696269               0.660
# 1  0      0.776      0.743  0.633333        0.761726               0.660
# 2  1      0.899      0.891  0.475000        0.717814               0.814
# 3  1      0.907      0.972  0.450000        0.734642               0.785
# 4  1      0.905      0.993  0.806250        0.915409               0.909
#
#    R (FSRSv3)  R (FSRSv4)  R (FSRS-4.5)  R (FSRS-5)  R (FSRS-6)  \
# 0       0.720       0.545         0.640       0.603       0.660
# 1       0.720       0.545         0.640       0.603       0.660
# 2       0.917       0.754         0.746       0.729       0.814
# 3       0.806       0.697         0.799       0.775       0.785
# 4       0.953       0.912         0.942       0.933       0.909
#
#    R (ADVERSARIAL)
# 0              1.0
# 1              1.0
# 2              0.5
# 3              0.6
# 4              0.9

# %%
df.describe()
# Out:
#                    y      R (SM-16)      R (SM-17)        R (AVG)  \
# count  652278.000000  652278.000000  652278.000000  652278.000000
# mean        0.869229       0.854864       0.886326       0.867499
# std         0.337150       0.145658       0.127711       0.056096
# min         0.000000       0.005000       0.000000       0.064286
# 25%         1.000000       0.822000       0.847000       0.837004
# 50%         1.000000       0.905000       0.912000       0.880738
# 75%         1.000000       0.945000       0.982000       0.903901
# max         1.000000       0.999000       1.000000       0.996970
#
#        R (MOVING-AVG)  R (FSRS-6-default)     R (FSRSv3)     R (FSRSv4)  \
# count   652278.000000       652278.000000  652278.000000  652278.000000
# mean         0.864028            0.801353       0.833819       0.839955
# std          0.086665            0.118994       0.165922       0.152060
# min          0.134825            0.231000       0.000000       0.004000
# 25%          0.826541            0.736000       0.797000       0.796000
# 50%          0.880813            0.825000       0.886000       0.888000
# 75%          0.921979            0.890000       0.937000       0.941000
# max          0.997495            1.000000       1.000000       1.000000
#
#         R (FSRS-4.5)     R (FSRS-5)     R (FSRS-6)  R (ADVERSARIAL)
# count  652278.000000  652278.000000  652278.000000    652278.000000
# mean        0.846337       0.845234       0.855837         0.869220
# std         0.133504       0.134621       0.095522         0.260804
# min         0.031000       0.031000       0.207000         0.000000
# 25%         0.798000       0.797000       0.810000         0.900000
# 50%         0.886000       0.885000       0.876000         1.000000
# 75%         0.939000       0.939000       0.924000         1.000000
# max         1.000000       1.000000       1.000000         1.000000

# %%
from utils import cross_comparison_plus
import itertools

results = []

all_algorithms = ["FSRS-6", "FSRS-5", "FSRS-4.5", "FSRSv4", "FSRSv3", "SM-17", "SM-16", "AVG", "MOVING-AVG"]

for player, referee in itertools.combinations(all_algorithms, 2):
    results.append(cross_comparison_plus(df, player, referee))
results
# Out:
# [{'FSRS-5_evaluated_by_FSRS-6': 0.082, 'FSRS-6_evaluated_by_FSRS-5': 0.0265},
#  {'FSRS-4.5_evaluated_by_FSRS-6': 0.0795,
#   'FSRS-6_evaluated_by_FSRS-4.5': 0.0253},
#  {'FSRSv4_evaluated_by_FSRS-6': 0.1091, 'FSRS-6_evaluated_by_FSRSv4': 0.0296},
#  {'FSRSv3_evaluated_by_FSRS-6': 0.1479, 'FSRS-6_evaluated_by_FSRSv3': 0.0316},
#  {'SM-17_evaluated_by_FSRS-6': 0.1023, 'FSRS-6_evaluated_by_SM-17': 0.0358},
#  {'SM-16_evaluated_by_FSRS-6': 0.1223, 'FSRS-6_evaluated_by_SM-16': 0.024},
#  {'AVG_evaluated_by_FSRS-6': 0.075, 'FSRS-6_evaluated_by_AVG': 0.027},
#  {'MOVING-AVG_evaluated_by_FSRS-6': 0.0731,
#   'FSRS-6_evaluated_by_MOVING-AVG': 0.0386},
#  {'FSRS-4.5_evaluated_by_FSRS-5': 0.0327,
#   'FSRS-5_evaluated_by_FSRS-4.5': 0.0381},
#  {'FSRSv4_evaluated_by_FSRS-5': 0.1026, 'FSRS-5_evaluated_by_FSRSv4': 0.0737},
#  {'FSRSv3_evaluated_by_FSRS-5': 0.1361, 'FSRS-5_evaluated_by_FSRSv3': 0.0596},
#  {'SM-17_evaluated_by_FSRS-5': 0.0989, 'FSRS-5_evaluated_by_SM-17': 0.0811},
#  {'SM-16_evaluated_by_FSRS-5': 0.1089, 'FSRS-5_evaluated_by_SM-16': 0.0581},
#  {'AVG_evaluated_by_FSRS-5': 0.0689, 'FSRS-5_evaluated_by_AVG': 0.0766},
#  {'MOVING-AVG_evaluated_by_FSRS-5': 0.0708,
#   'FSRS-5_evaluated_by_MOVING-AVG': 0.0842},
#  {'FSRSv4_evaluated_by_FSRS-4.5': 0.1054,
#   'FSRS-4.5_evaluated_by_FSRSv4': 0.0756},
#  {'FSRSv3_evaluated_by_FSRS-4.5': 0.1376,
#   'FSRS-4.5_evaluated_by_FSRSv3': 0.0597},
#  {'SM-17_evaluated_by_FSRS-4.5': 0.0989,
#   'FSRS-4.5_evaluated_by_SM-17': 0.0788},
#  {'SM-16_evaluated_by_FSRS-4.5': 0.1092,
#   'FSRS-4.5_evaluated_by_SM-16': 0.0559},
#  {'AVG_evaluated_by_FSRS-4.5': 0.0692, 'FSRS-4.5_evaluated_by_AVG': 0.0744},
#  {'MOVING-AVG_evaluated_by_FSRS-4.5': 0.0707,
#   'FSRS-4.5_evaluated_by_MOVING-AVG': 0.0822},
#  {'FSRSv3_evaluated_by_FSRSv4': 0.1152, 'FSRSv4_evaluated_by_FSRSv3': 0.0607},
#  {'SM-17_evaluated_by_FSRSv4': 0.0969, 'FSRSv4_evaluated_by_SM-17': 0.106},
#  {'SM-16_evaluated_by_FSRSv4': 0.1026, 'FSRSv4_evaluated_by_SM-16': 0.083},
#  {'AVG_evaluated_by_FSRSv4': 0.0651, 'FSRSv4_evaluated_by_AVG': 0.1015},
#  {'MOVING-AVG_evaluated_by_FSRSv4': 0.0679,
#   'FSRSv4_evaluated_by_MOVING-AVG': 0.1083},
#  {'SM-17_evaluated_by_FSRSv3': 0.0891, 'FSRSv3_evaluated_by_SM-17': 0.1406},
#  {'SM-16_evaluated_by_FSRSv3': 0.0861, 'FSRSv3_evaluated_by_SM-16': 0.1143},
#  {'AVG_evaluated_by_FSRSv3': 0.0531, 'FSRSv3_evaluated_by_AVG': 0.1365},
#  {'MOVING-AVG_evaluated_by_FSRSv3': 0.0555,
#   'FSRSv3_evaluated_by_MOVING-AVG': 0.1412},
#  {'SM-16_evaluated_by_SM-17': 0.1138, 'SM-17_evaluated_by_SM-16': 0.0862},
#  {'AVG_evaluated_by_SM-17': 0.0454, 'SM-17_evaluated_by_AVG': 0.0774},
#  {'MOVING-AVG_evaluated_by_SM-17': 0.0509,
#   'SM-17_evaluated_by_MOVING-AVG': 0.088},
#  {'AVG_evaluated_by_SM-16': 0.051, 'SM-16_evaluated_by_AVG': 0.1084},
#  {'MOVING-AVG_evaluated_by_SM-16': 0.0533,
#   'SM-16_evaluated_by_MOVING-AVG': 0.114},
#  {'MOVING-AVG_evaluated_by_AVG': 0.0326,
#   'AVG_evaluated_by_MOVING-AVG': 0.0462}]

# %%
import numpy as np

final_results = {}

for player in all_algorithms:
    universal_metrics = []
    for result in results:
        for key, value in result.items():
            if key.startswith(player):
                universal_metrics.append(value)
    final_results[player] = np.array(universal_metrics).mean().round(4)

# Sort by value (ascending, lower is better)
sorted_results = sorted(final_results.items(), key=lambda x: x[1])

# Display result in markdown table format, bold the best algorithm and its metric
print("| Algorithm | Universal Metric↓ |")
print("|-----------|------------------|")
for i, (algo, metric) in enumerate(sorted_results):
    if i == 0:
        print(f"| **{algo}** | **{metric:.4f}** |")
    else:
        print(f"| {algo} | {metric:.4f} |")
# Out:
# | Algorithm | Universal Metric↓ |
# |-----------|------------------|
# | **FSRS-6** | **0.0298** |
# | AVG | 0.0592 |
# | MOVING-AVG | 0.0594 |
# | FSRS-4.5 | 0.0673 |
# | FSRS-5 | 0.0692 |
# | SM-17 | 0.0922 |
# | FSRSv4 | 0.0971 |
# | SM-16 | 0.1082 |
# | FSRSv3 | 0.1337 |
