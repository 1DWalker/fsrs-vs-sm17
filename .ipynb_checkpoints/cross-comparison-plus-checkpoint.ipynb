# %% [markdown]
# The cross comparison method is proposed by Woz: https://supermemo.guru/wiki/Universal_metric_for_cross-comparison_of_spaced_repetition_algorithms#Algorithmic_contest:_SuperMemo_2_vs._SuperMemo_17

# %%
import pandas as pd
from pathlib import Path

dfs = []

for file in Path("./raw").glob("*.csv"):
    dfs.append(pd.read_csv(file))

df = pd.concat(dfs, ignore_index=True)
df.rename(columns={"R (SM17)": "R (SM-17)"}, inplace=True)
df.rename(columns={"R (SM16)": "R (SM-16)"}, inplace=True)
df.head()
# Out:
#    y  R (SM-16)  R (SM-17)   R (AVG)  R (MOVING-AVG)  R (LSTM)  \
# 0  1      0.836      0.764  0.900000        0.696269     0.504
# 1  0      0.776      0.743  0.633333        0.761726     0.513
# 2  1      0.899      0.891  0.475000        0.717814     0.827
# 3  1      0.907      0.972  0.450000        0.734642     0.966
# 4  1      0.905      0.993  0.806250        0.915409     0.983
#
#    R (FSRS-6-default)  R (FSRSv3)  R (FSRSv4)  R (FSRS-4.5)  R (FSRS-5)  \
# 0               0.660       0.720       0.545         0.640       0.603
# 1               0.660       0.720       0.545         0.640       0.603
# 2               0.814       0.917       0.754         0.746       0.729
# 3               0.785       0.806       0.697         0.799       0.775
# 4               0.909       0.953       0.912         0.942       0.933
#
#    R (FSRS-6)  R (ADVERSARIAL-UM)  R (ADVERSARIAL-UM+)
# 0       0.660                 1.0                1.000
# 1       0.660                 1.0                1.000
# 2       0.814                 0.5                0.860
# 3       0.785                 0.6                0.875
# 4       0.909                 0.9                0.990

# %%
df.describe()
# Out:
#                    y      R (SM-16)      R (SM-17)        R (AVG)  \
# count  652278.000000  652278.000000  652278.000000  652278.000000
# mean        0.869229       0.854864       0.886326       0.867499
# std         0.337150       0.145658       0.127711       0.056096
# min         0.000000       0.005000       0.000000       0.064286
# 25%         1.000000       0.822000       0.847000       0.837004
# 50%         1.000000       0.905000       0.912000       0.880738
# 75%         1.000000       0.945000       0.982000       0.903901
# max         1.000000       0.999000       1.000000       0.996970
#
#        R (MOVING-AVG)       R (LSTM)  R (FSRS-6-default)     R (FSRSv3)  \
# count   652278.000000  652278.000000       652278.000000  652278.000000
# mean         0.864028       0.872067            0.801353       0.833819
# std          0.086665       0.097335            0.118994       0.165922
# min          0.134825       0.157000            0.231000       0.000000
# 25%          0.826541       0.834000            0.736000       0.797000
# 50%          0.880813       0.900000            0.825000       0.886000
# 75%          0.921979       0.940000            0.890000       0.937000
# max          0.997495       0.999000            1.000000       1.000000
#
#           R (FSRSv4)   R (FSRS-4.5)     R (FSRS-5)     R (FSRS-6)  \
# count  652278.000000  652278.000000  652278.000000  652278.000000
# mean        0.839953       0.846340       0.845234       0.855835
# std         0.152065       0.133504       0.134621       0.095530
# min         0.004000       0.031000       0.031000       0.207000
# 25%         0.797000       0.798000       0.797000       0.810000
# 50%         0.888000       0.886000       0.885000       0.876000
# 75%         0.941000       0.939000       0.939000       0.924000
# max         1.000000       1.000000       1.000000       1.000000
#
#        R (ADVERSARIAL-UM)  R (ADVERSARIAL-UM+)
# count       652278.000000        652278.000000
# mean             0.869222             0.868482
# std              0.260991             0.101264
# min              0.000000             0.000000
# 25%              0.900000             0.825000
# 50%              1.000000             0.895000
# 75%              1.000000             0.940000
# max              1.000000             1.000000

# %%
from utils import cross_comparison_plus
import itertools

results = []

all_algorithms = ["FSRS-6", "FSRS-5", "FSRS-4.5", "FSRSv4", "FSRSv3", "SM-17", "SM-16", "LSTM", "AVG", "MOVING-AVG"]

for player, referee in itertools.combinations(all_algorithms, 2):
    results.append(cross_comparison_plus(df, player, referee))
results

# %%
import numpy as np

final_results = {}

for player in all_algorithms:
    universal_metrics = []
    for result in results:
        for key, value in result.items():
            if key.startswith(player):
                universal_metrics.append(value)
    final_results[player] = np.array(universal_metrics).mean().round(4)

# Sort by value (ascending, lower is better)
sorted_results = sorted(final_results.items(), key=lambda x: x[1])

# Display result in markdown table format, bold the best algorithm and its metric
print("| Algorithm | Universal Metric+↓ |")
print("|-----------|------------------|")
for i, (algo, metric) in enumerate(sorted_results):
    if i == 0:
        print(f"| **{algo}** | **{metric:.4f}** |")
    else:
        print(f"| {algo} | {metric:.4f} |")
